# %%
import pandas as pd
import csv
import datetime
import matplotlib.pyplot as plt
f = open('week1.csv', 'r')
flag = -1
tms = []
data = []
reader = csv.reader(f, delimiter=',')
for row in reader:
	if flag == -1:
		flag = 0
		continue
	prot = row[2].replace(' ', '')
	if prot != 'TCP':
		continue 
	# print(row[2])
	try:
		data.append(int(row[8]))
		tms.append(datetime.datetime.strptime(row[0], '%Y-%m-%d %H:%M:%S.%f'))
	except Exception as e:
		continue
	if len(tms) > 1000000:
		break
st = tms[0]
cnt = 0
sums = 0
points = []
x = []
y= []
#print(len(tms), len(data))
for i in range(len(data)):
	if tms[i] > st + datetime.timedelta(seconds = 60):
		st = st + datetime.timedelta(seconds = 60)
		points.append([cnt, sums])
		x.append(cnt)
		y.append(sums)
		# print([cnt, sums])
		cnt = 0
		sums = 0
	sums = sums + data[i]
	cnt = cnt+1
	if len(points) > 100000:
		break


io = x
x=[]
for i in io:
    if i > 100:
        x.append(i)

        
        
        
import csv
from datetime import timedelta, date
start_date = date(2013, 1, 1)
d = start_date
delta = datetime.timedelta(days=1)
with open('flow_col.csv', mode='w') as f:
    w = csv.writer(f, delimiter=',', quotechar='"', quoting=csv.QUOTE_MINIMAL)
    for i in range(len(x)):
        w.writerow([d.strftime("%Y-%m-%d"), float(x[i])])
        d+=delta
data = pd.read_csv('flow_col.csv',index_col=0)
data.head()
data.index = pd.to_datetime(data.index)
import plotly
from plotly.plotly import plot_mpl
plotly.tools.set_credentials_file(username='Dipendrasingh', api_key='3QsW03xW7rQadLNm9AVj')
from statsmodels.tsa.seasonal import seasonal_decompose
result = seasonal_decompose(data, model='multiplicative')
fig = result.plot()
plot_mpl(fig)
from pyramid.arima import auto_arima
stepwise_model = auto_arima(data, start_p=1, start_q=1,
                           max_p=3, max_q=3, m=12,
                           start_P=0, seasonal=True,
                           d=1, D=1, trace=True,
                           error_action='ignore',  
                           suppress_warnings=True, 
                           stepwise=True)
print(stepwise_model.aic())
# Out:
# Fit ARIMA: order=(1, 1, 1) seasonal_order=(0, 1, 1, 12); AIC=8269.990, BIC=8291.211, Fit time=5.995 seconds
# Fit ARIMA: order=(0, 1, 0) seasonal_order=(0, 1, 0, 12); AIC=8643.962, BIC=8652.450, Fit time=0.082 seconds
# Fit ARIMA: order=(1, 1, 0) seasonal_order=(1, 1, 0, 12); AIC=8498.006, BIC=8514.983, Fit time=2.446 seconds
# Fit ARIMA: order=(0, 1, 1) seasonal_order=(0, 1, 1, 12); AIC=8310.215, BIC=8327.192, Fit time=2.260 seconds
# Fit ARIMA: order=(1, 1, 1) seasonal_order=(1, 1, 1, 12); AIC=8271.168, BIC=8296.633, Fit time=5.347 seconds
# Fit ARIMA: order=(1, 1, 1) seasonal_order=(0, 1, 0, 12); AIC=8601.174, BIC=8618.151, Fit time=0.709 seconds
# Fit ARIMA: order=(1, 1, 1) seasonal_order=(0, 1, 2, 12); AIC=8271.108, BIC=8296.573, Fit time=9.541 seconds
# Fit ARIMA: order=(1, 1, 1) seasonal_order=(1, 1, 2, 12); AIC=8273.976, BIC=8303.685, Fit time=10.673 seconds
# Fit ARIMA: order=(2, 1, 1) seasonal_order=(0, 1, 1, 12); AIC=8271.799, BIC=8297.264, Fit time=6.000 seconds
# Fit ARIMA: order=(1, 1, 0) seasonal_order=(0, 1, 1, 12); AIC=8312.420, BIC=8329.397, Fit time=1.527 seconds
# Fit ARIMA: order=(1, 1, 2) seasonal_order=(0, 1, 1, 12); AIC=8311.161, BIC=8336.626, Fit time=4.961 seconds
# Fit ARIMA: order=(0, 1, 0) seasonal_order=(0, 1, 1, 12); AIC=8314.125, BIC=8326.857, Fit time=0.924 seconds
# Fit ARIMA: order=(2, 1, 2) seasonal_order=(0, 1, 1, 12); AIC=8271.063, BIC=8300.773, Fit time=7.227 seconds
# Total fit time: 57.697 seconds
# 8269.99035794515

# %%
print(len(data))
train = data.loc[:'2013-03-06']
test = data.loc['2013-03-07':]
stepwise_model.fit(train)
# Out:
# 528
# ARIMA(callback=None, disp=0, maxiter=50, method=None, order=(1, 1, 1),
#    out_of_sample_size=0, scoring='mse', scoring_args={},
#    seasonal_order=(0, 1, 1, 12), solver='lbfgs', start_params=None,
#    suppress_warnings=True, transparams=True, trend='c')

# %%
future_forecast = stepwise_model.predict(n_periods=464)
future_forecast = pd.DataFrame(future_forecast,index = test.index,columns=['Prediction'])
pd.concat([test,future_forecast],axis=1).plot()
pd.concat([data,future_forecast],axis=1).plot()
